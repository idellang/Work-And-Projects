# %%
#load the data

import pandas as pd

data = pd.read_csv('wide_area_travel.csv')
data
# Out:
#          vehicle                   origin     destination  origin_lat  \
# 0        NBQ2184                  MAUNONG  Tanauan Garage   14.167896
# 1        NBQ2184       TANAUAN-IMUS ROUTE  Tanauan Garage   14.272338
# 2        NBQ2184       TANAUAN-IMUS ROUTE  Tanauan Garage   14.272306
# 3        NBQ2184  TANAUAN-GUIGUINTO ROUTE  Tanauan Garage   14.498420
# 4        NBQ2185              San Pedro 2  Tanauan Garage   14.358771
# ..           ...                      ...             ...         ...
# 339      AAB1199           Tanauan Garage  Tanauan Garage   14.106657
# 340  1801-119035        8070 BCFG Calamba  Tanauan Garage   14.224830
# 341       WIV290           Tanauan Garage  Tanauan Garage   14.106657
# 342      NBQ2184           Tanauan Garage  Tanauan Garage   14.106657
# 343      NBQ2184           Tanauan Garage  Tanauan Garage   14.106657
#
#      origin_long  destination_lat  destination_long  \
# 0     121.150633        14.106657        121.124166
# ...

# %%
coordinates = [(x,y) for x,y in zip(data['origin_long'], data['origin_lat'])]
data['origin_coord'] = coordinates
data
# Out:
#          vehicle                   origin     destination  origin_lat  \
# 0        NBQ2184                  MAUNONG  Tanauan Garage   14.167896
# 1        NBQ2184       TANAUAN-IMUS ROUTE  Tanauan Garage   14.272338
# 2        NBQ2184       TANAUAN-IMUS ROUTE  Tanauan Garage   14.272306
# 3        NBQ2184  TANAUAN-GUIGUINTO ROUTE  Tanauan Garage   14.498420
# 4        NBQ2185              San Pedro 2  Tanauan Garage   14.358771
# ..           ...                      ...             ...         ...
# 339      AAB1199           Tanauan Garage  Tanauan Garage   14.106657
# 340  1801-119035        8070 BCFG Calamba  Tanauan Garage   14.224830
# 341       WIV290           Tanauan Garage  Tanauan Garage   14.106657
# 342      NBQ2184           Tanauan Garage  Tanauan Garage   14.106657
# 343      NBQ2184           Tanauan Garage  Tanauan Garage   14.106657
#
#      origin_long  destination_lat  destination_long  \
# 0     121.150633        14.106657        121.124166
# ...

# %%
coordinates = [(x,y) for x,y in zip(data['destination_long'], data['destination_lat'])]
data['destination_coord'] = coordinates
data
# Out:
#          vehicle                   origin     destination  origin_lat  \
# 0        NBQ2184                  MAUNONG  Tanauan Garage   14.167896
# 1        NBQ2184       TANAUAN-IMUS ROUTE  Tanauan Garage   14.272338
# 2        NBQ2184       TANAUAN-IMUS ROUTE  Tanauan Garage   14.272306
# 3        NBQ2184  TANAUAN-GUIGUINTO ROUTE  Tanauan Garage   14.498420
# 4        NBQ2185              San Pedro 2  Tanauan Garage   14.358771
# ..           ...                      ...             ...         ...
# 339      AAB1199           Tanauan Garage  Tanauan Garage   14.106657
# 340  1801-119035        8070 BCFG Calamba  Tanauan Garage   14.224830
# 341       WIV290           Tanauan Garage  Tanauan Garage   14.106657
# 342      NBQ2184           Tanauan Garage  Tanauan Garage   14.106657
# 343      NBQ2184           Tanauan Garage  Tanauan Garage   14.106657
#
#      origin_long  destination_lat  destination_long  \
# 0     121.150633        14.106657        121.124166
# ...

# %%
data.loc[:, ['vehicle','origin','destination','origin_coord','origin_lat','origin_long','destination_coord','destination_lat','destination_long']]
# Out:
#          vehicle                   origin     destination  \
# 0        NBQ2184                  MAUNONG  Tanauan Garage
# 1        NBQ2184       TANAUAN-IMUS ROUTE  Tanauan Garage
# 2        NBQ2184       TANAUAN-IMUS ROUTE  Tanauan Garage
# 3        NBQ2184  TANAUAN-GUIGUINTO ROUTE  Tanauan Garage
# 4        NBQ2185              San Pedro 2  Tanauan Garage
# ..           ...                      ...             ...
# 339      AAB1199           Tanauan Garage  Tanauan Garage
# 340  1801-119035        8070 BCFG Calamba  Tanauan Garage
# 341       WIV290           Tanauan Garage  Tanauan Garage
# 342      NBQ2184           Tanauan Garage  Tanauan Garage
# 343      NBQ2184           Tanauan Garage  Tanauan Garage
#
#                              origin_coord  origin_lat  origin_long  \
# 0    (121.150632755386, 14.1678957171158)   14.167896   121.150633
# 1       (121.0396701226, 14.272337850988)   14.272338   121.039670
# ...
