# %%
import pandas as pd 
import numpy as np

# %%
## load data 

geofences = pd.read_csv('Geofence Library/TMSUITE-Geofences-asof-0517-Formatted.csv')
dcs = pd.read_csv('Geofence Library/Nestle-P-Geofences.csv')

# %%
## select column names for geofences

geofences = geofences.loc[:, ['name','group_names','geofence_code']]

# %%
## create new column for group names
## optional

def extract_group(row):
    '''Create mapping for fixed group names'''
    if 'Nestle' in row['group_names']:
        return 'Nestle'
    elif 'DHL' in row['group_names'] :
        return 'DHL'
    elif 'HAVI' in row['group_names'] :
        return 'HAVI'
    else:
        return np.nan


geofences['group_names_new'] = geofences.apply(extract_group, axis = 1)

# %%
# combine two dataframes

geofences_with_dcs = pd.merge(geofences, dcs, how = 'left', left_on = 'name', right_on = 'Dropoffs')

# %%
# drop duplicates 

geofences_with_dcs.drop_duplicates(inplace = True)

# %%
# create new columns dcs and num dcs
nunique_pickups = geofences_with_dcs.groupby('name')['Pickups'].nunique()
pickups = geofences_with_dcs.groupby('name')['Pickups'].apply(list)
nunique_pickups.name = 'num_dc'
pickups.name = 'DC'

# %%
# join dataframes
geofences_with_dcs = geofences_with_dcs.loc[:, ['name','group_names','geofence_code','group_names_new']].drop_duplicates().set_index('name').join(nunique_pickups).join(pickups)

# %%
geofences_with_dcs['DC'] = geofences_with_dcs['DC'].apply(str).str.replace('nan','None').str.replace("\[|\]|\'",'')
# Out:
# <ipython-input-92-b1fe59158ebb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   geofences_with_dcs['DC'] = geofences_with_dcs['DC'].apply(str).str.replace('nan','None').str.replace("\[|\]|\'",'')

# %%
geofences_with_dcs.sort_values(by = 'num_dc', ascending = False)[:50]
# Out:
#                                                               group_names  \
# name
# PH Batino Grocery - Destination                     ['Nestle', 'Webcast']
# PH Meycauayan Grocery - Destination                 ['Nestle', 'Webcast']
# PH Bacolod - Mansilingan DC - Destination           ['Nestle', 'Webcast']
# PH Mandaue Grocery - Destination                    ['Nestle', 'Webcast']
# PH Cagayan Grocery - Destination                    ['Nestle', 'Webcast']
# PH Tarlac Grocery - Destination                     ['Nestle', 'Webcast']
# Humabon Distributors - Malinta                      ['Nestle', 'Webcast']
# Right Moves, Inc.                                   ['Nestle', 'Webcast']
# PH Antonina - Destination                           ['Nestle', 'Webcast']
# Optimized Customer Solutions, Inc.                  ['Nestle', 'Webcast']
# Right Goods South Operations Inc. - Las Pinas       ['Nestle', 'Webcast']
# Demopower Philippines                               ['Nestle', 'Webcast']
# Team Onground Inc.                                  ['Nestle', 'Webcast']
# PH Portion Fillers 2 - Destination                  ['Nestle', 'Webcast']
# PH RM Foods, Inc. - Destination                     ['Nestle', 'Webcast']
# Napintas - La Union Baguio                          ['Nestle', 'Webcast']
# Optimized Customer Solutions, Inc. - Cavite         ['Nestle', 'Webcast']
# Convenience Distribution Inc.                       ['Nestle', 'Webcast']
# Optimized Customer Solutions, Inc.-                 ['Nestle', 'Webcast']
# Alphabetsoup Inc.                                   ['Nestle', 'Webcast']
# Fast Cargo Logistics Corporation                               ['Nestle']
# Metro Opao Warehouse                                           ['Nestle']
# Napintas - Mandaue Cebu                             ['Nestle', 'Webcast']
# Rosabaya Distributors Incorporated                  ['Nestle', 'Webcast']
# OCSI - San Pablo                                    ['Nestle', 'Webcast']
# PH Cabuyao FG UHT - Source                          ['Nestle', 'Webcast']
# Grand Chamonix Marketing Inc.                       ['Nestle', 'Webcast']
# PH CP QUAENSA Foods Inc. - Destination              ['Nestle', 'Webcast']
# Actiserve Corp.                                     ['Nestle', 'Webcast']
# Napintas Logistics and Distribution - Santa Bar...  ['Nestle', 'Webcast']
# Lawson Philippines, Inc. - Taguig                              ['Nestle']
# GG & G Distributors - Tarlac                        ['Nestle', 'Webcast']
# GG & G Distributors                                 ['Nestle', 'Webcast']
# PH HO MAO NPI 2                                                ['Nestle']
# Benson Industrial Cold Storage                                 ['Nestle']
# IQ Packaging Systems Incorporated                   ['Nestle', 'Webcast']
# Valiant Distribution - Taguig DC                    ['Nestle', 'Webcast']
# PH Cofipack - Destination                           ['Nestle', 'Webcast']
# Chowking - Pasig                                    ['Nestle', 'Webcast']
# J.A.M.C. Marketing Inc.                             ['Nestle', 'Webcast']
# Save More - Xentro Mall Antipolo                    ['Nestle', 'Webcast']
# Ever Plus Superstore - Santolan                     ['Nestle', 'Webcast']
# FDC - CDO                                           ['Nestle', 'Webcast']
# Rosabaya Distributors - Tagum                       ['Nestle', 'Webcast']
# SM Hypermarket - FTI Taguig                         ['Nestle', 'Webcast']
# MDSI - Midsayap                                     ['Nestle', 'Webcast']
# Twin Peak Marketing - Sorsogon                      ['Nestle', 'Webcast']
# Ultra Mega Multi Sales - Montalban                  ['Nestle', 'Webcast']
# Twin Peak Marketing Inc.                            ['Nestle', 'Webcast']
# CSI Warehouse Club - Santa Barbara                  ['Nestle', 'Webcast']
#
#                                                      geofence_code  \
# name
# PH Batino Grocery - Destination                           PH3C0570
# PH Meycauayan Grocery - Destination                       PH3C3442
# PH Bacolod - Mansilingan DC - Destination                 PH3C9294
# PH Mandaue Grocery - Destination                          PH3C0572
# PH Cagayan Grocery - Destination                          PH3C4622
# PH Tarlac Grocery - Destination                           PH3C9293
# Humabon Distributors - Malinta                      PHEC0003387019
# Right Moves, Inc.                                   PHEC0004333192
# PH Antonina - Destination                                 PH3C0601
# Optimized Customer Solutions, Inc.                  PHEC0000320075
# Right Goods South Operations Inc. - Las Pinas       PHEC0005900788
# Demopower Philippines                               PHEC0000359530
# Team Onground Inc.                                  PHEC0005172872
# PH Portion Fillers 2 - Destination                        PH3C0604
# PH RM Foods, Inc. - Destination                           PH3C0597
# Napintas - La Union Baguio                          PHEC0005455563
# Optimized Customer Solutions, Inc. - Cavite         PHEC0000593380
# Convenience Distribution Inc.                       PHEC0003160317
